# %% [markdown]
# http://bicycle1885.hatenablog.com/entry/2014/02/14/023734
# matplotlib入門 を参照しています

# %%
pylab inline --no-import-all
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=np.arange(-3,3,0.1)
y=np.sin(x)
plt.plot(x,y)

# %%
x=np.random.randn(30)
y=np.sin(x)+np.random.randn(30)
plt.plot(x,y,"ro") # "o"は小さい円(circle marker)

# %%
plt.hist(np.random.randn(1000))
# Out:
# (array([ 14.,  46.,  95., 169., 214., 217., 140.,  73.,  21.,  11.]),
#  array([-2.67518717, -2.12038992, -1.56559267, -1.01079541, -0.45599816,
#          0.0987991 ,  0.65359635,  1.20839361,  1.76319086,  2.31798812,
#          2.87278537]),
#  <a list of 10 Patch objects>)

# %%
plt.imshow(np.random.randn(100,100))

# %%
plt.imshow(np.random.randn(100,100))
plt.title("100×100 Matrix")
# Out:
# Text(0.5,1,'100×100 Matrix')
